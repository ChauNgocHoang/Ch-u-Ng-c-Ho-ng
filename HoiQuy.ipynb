# %% [markdown]
# <a href="https://colab.research.google.com/github/ChauNgocHoang/Chau-Ngoc-Hoang/blob/main/HoiQuy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hòi quy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('/content/Salary_Data.csv')
data.head()
x = data.drop(['Salary'],axis = True)
y = data['Salary']

# %%
# HỒI QUY
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('/content/Salary_Data.csv')
data.head()
x = data.drop(['Salary'],axis = True)
y = data['Salary']
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test= train_test_split(x,y,test_size= 0.2, random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
sns.pairplot(data)

# %%
plt.plot(x_train,y_train,'r.',label='Trend Data')
plt.xlabel('YearExperience')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test).round(1)
Col = pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Salary','Predicted Salary'])
Col
print('coeffient',model.coef_)
print('Intercept',model.intercept_)
#print('Accuracy',model.score(x_train,y_train))
print('Accuracy',model.score(x_test,y_test))
# Out:
# coeffient [9423.81532303]
# Intercept 25321.583011776813
# Accuracy 0.9024461774180497

# %%
plt.scatter(x_train,y_train,color ='red')
plt.plot(x_train,model.predict(x_train),color='blue')
plt.title('Salary vs Expeerience(Train set)')
plt.xlabel('Year of Exerience')
plt.ylabel('Salary')
plt.show()
